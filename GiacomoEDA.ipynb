# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_pop = pd.read_csv("/content/drive/Shared drives/MSD 23 Drive/Datasets/state_county_cbsa_population.csv")

# %%
list(df_pop['Geographic Area Name'].iloc[:52].unique())
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'Puerto Rico']

# %%
# first 52 rows are state-based
df_pop = df_pop.iloc[:52]

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# Map state names to USPS abbreviations
df_pop['Geographic Area Name'] = df_pop['Geographic Area Name'].map(us_state_to_abbrev)
# Keep years of interest: 2016-2019 (we lack 2020 in this dataset)
df_pop = df_pop[['Geographic Area Name', '2016_population', '2017_population', '2018_population', '2019_population']]

# %%
df_fac = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/treatment_facilities_2016_2020.csv')

# %%
for i in df_fac['STATE'].unique(): 
  if i not in
# Out:
#   File "<ipython-input-6-42f0851374bd>", line 2
#     if i not in
#                 ^
# SyntaxError: invalid syntax

# %%
states = df_fac['STATE'].unique()

# %%
df_fac['SRVC31'] = df_fac['SRVC31'].replace(['1'], [1])
df_fac['SRVC31'] = df_fac['SRVC31'].replace(['0'], [0])

df_fac2 = df_fac[df_fac['SRVC31'] != 'M']

# %%
# Number of facilities per state offering SRVC31 = programme for patients with MHD (mental health disorder) and SUD
df_fac2.groupby('STATE')['SRVC31'].sum().reset_index().plot(x = 'STATE', y = 'SRVC31', kind = 'bar')

# %%
plt.figure(figsize = (10, 5))
df_fac.groupby('STATE')['TREATMT'].sum().reset_index().plot(x = 'STATE', y = 'TREATMT', kind = 'bar')

# %%
df_treatments = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/treatments_2017-2020.csv')

# %%
##'DAYWAIT'
##'PREG'
##'SRVC33'
## GENDER

women = df_treatments[df_treatments['GENDER'] == 2]
pregnant_women = women[(women['PREG'] == 1) & (women['DAYWAIT'] != -9)]
nonpregnant_women = women[(women['PREG'] == 2) & (women['DAYWAIT'] != -9)]

# %%
yp, xp, _ = plt.hist(pregnant_women['DAYWAIT'], bins=[0, 1, 2, 3, 4, 5]);
yn, xn, _ = plt.hist(nonpregnant_women['DAYWAIT'], bins=[0, 1, 2, 3, 4, 5]);

# %%
yp = yp/sum(yp)
yn = yn/sum(yn)

# %%
plt.bar(xp[1:], yp, alpha = 0.5, label = 'Pregnant')
plt.bar(xn[1:], yn, alpha = 0.5, label = 'Non pregnant')
plt.legend(frameon = False)
