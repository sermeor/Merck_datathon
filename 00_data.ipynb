# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')

# %%
# load data
df_treatments = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/treatments_2017-2020.csv')
df_treatment_facilities = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/treatment_facilities_2016_2020.csv')
df_pop = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/state_county_cbsa_population.csv')
df_social_1yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_social_1yr.csv')
df_social_5yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_social_5yr.csv')
df_housing_1yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_housing_1yr.csv')
df_housing_5yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_housing_5yr.csv')
df_economics_1yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_economics_1yr.csv')
df_economics_5yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_economics_5yr.csv')
df_demographics_1yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_demographics_1yr.csv')
df_demographics_5yr = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/acs_demographics_5yr.csv')

# %%
df_treatments.SERVICES.value_counts()

# %%
for i in df_treatments.columns:
  print(i, round(sum(df_treatments[i] == -9)/len(df_treatments), 2))

# %%
df_treatments[df_treatments['PREG'] != -9]['GENDER'].value_counts()

# %%
df_treatments[df_treatments['PREG'] == -9]['GENDER'].value_counts()

# %%
for i in df_treatment_facilities.columns:
  print(i, round(sum(df_treatment_facilities[i] == 'M')/len(df_treatment_facilities), 2))

# %%
df_treatments.columns
