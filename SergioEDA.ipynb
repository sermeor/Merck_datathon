# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
#
#
# *   PSYPROB - Boolean mental illness.
# 1:Yes
# 2:No
# *   DAYWAIT - Waiting time to initiate treatment.
# 0:0days
# 1:1-7days
# 2:8-14days
# 3:15-30days
# 4:>31days
#
#
#
# QUESTION: Are wait times longer or shorter for patients with mental illness?
# Do this decreases the probability of a succesfull treatment.

# %%
df_treatments = pd.read_csv('/content/drive/Shared drives/MSD 23 Drive/Datasets/treatments_2017-2020.csv')

# %%
## Extracting New Jersey rows and PSYPROB answered. 

##
##(df_treatments['statename'] == 'New Jersey') &

df = df_treatments[(df_treatments['PSYPROB'] != -9) & (df_treatments['DAYWAIT'] != -9)]

x1 = df[df['PSYPROB'] == 1]['DAYWAIT'].value_counts()
x1 = x1/sum(x1)

x2 = df[df['PSYPROB'] == 2]['DAYWAIT'].value_counts()
x2 = x2/sum(x2)


#df_NJ['PSYPROB'].value_counts()

# %%
print(x1)
print('---------')
print(x2)

# %%
x1.hist()

# %%
df_treatments
