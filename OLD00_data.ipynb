# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/Shareddrives/'MSD 23 Drive'/Datasets

# %%
df = pd.read_csv('acs_demographics_1yr.csv')
df.head(2)

# %%
os.listdir()

# %%
# load data
df_treatments = pd.read_csv( 'treatments_2017-2020.csv')
df_treatment_facilities = pd.read_csv('treatment_facilities_2016_2020.csv')
df_pop = pd.read_csv( 'state_county_cbsa_population.csv')
df_social_1yr = pd.read_csv( 'acs_social_1yr.csv')
df_social_5yr = pd.read_csv('acs_social_5yr.csv')
df_housing_1yr = pd.read_csv('acs_housing_1yr.csv')
df_housing_5yr = pd.read_csv('acs_housing_5yr.csv')
df_economics_1yr = pd.read_csv( 'acs_economics_1yr.csv')
df_economics_5yr = pd.read_csv( 'acs_economics_5yr.csv')
df_demographics_1yr = pd.read_csv('acs_demographics_1yr.csv')
df_demographics_5yr = pd.read_csv('acs_demographics_5yr.csv')

# %%
print(df_treatments.shape)
df_treatments.head(2)

# %%
df_treatments.SERVICES.value_counts()

# %%
print(df_pop.shape)
df_pop.head(2)

# %%
print(df_social_1yr.shape)
df_social_1yr.head(2)

# %%
print(df_treatments.shape)
df_treatments.head(2)

# %%
print(df_treatments.columns)

# %%
df_treatments[df_treatments.SUB1 != -9].SUB1.hist()
